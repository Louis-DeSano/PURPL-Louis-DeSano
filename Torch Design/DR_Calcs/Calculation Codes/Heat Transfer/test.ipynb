# %%
# check spreadsheet was given as argument and open it

#unpack material properties and sim setup
CTE = 12e-6
E = 200e9
A = 3.6e-3
epsilon_t=  CTE * (90-20)
sigma_t = epsilon_t * E
F = sigma_t * A

print(F)
